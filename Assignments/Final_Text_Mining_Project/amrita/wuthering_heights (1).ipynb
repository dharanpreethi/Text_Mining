# %% [markdown]
# 9)Wuthering heights by Emily Bronte

# %%
#WORDCLOUD

# Install necessary libraries
# !pip install wordcloud

from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from google.colab import files

# Upload a text file
uploaded = files.upload()

# Get the filename from the uploaded files
filename = list(uploaded.keys())[0]

# Read the text file
with open(filename, 'r', encoding='utf-8', errors='ignore') as f:
    text = f.read()

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400,
                      background_color='white',
                      stopwords=STOPWORDS,
                      min_font_size=10).generate(text)

# Display the generated image:
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
# Out:
# ...
#      <input type="file" id="files-b1fcc043-052f-4e87-9b10-b9049e00a6e6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1fcc043-052f-4e87-9b10-b9049e00a6e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
 #generate a heatmap of uploaded  text file

import matplotlib.pyplot as plt
import numpy as np
from google.colab import files
# Install necessary libraries
# !pip install wordcloud

uploaded = files.upload()
filename = list(uploaded.keys())[0]

# Read the text file
with open(filename, 'r', encoding='utf-8', errors='ignore') as f:
    text = f.read()

# Sample heatmap data (replace with actual text analysis)
data = np.random.rand(10, 10)

# Create a heatmap
plt.imshow(data, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.title('Heatmap of Uploaded File')
plt.show()
# Out:
# ...
#      <input type="file" id="files-46233023-c518-45cd-83ed-a6f4a621e446" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46233023-c518-45cd-83ed-a6f4a621e446">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# A pie chart of words used in an uploade text file

from collections import Counter
import matplotlib.pyplot as plt

# Assuming 'text' variable from the previous code block contains the file content

# Tokenize the text (split into words)
words = text.lower().split()

# Remove stop words (optional)
stop_words = set(STOPWORDS) # Use the STOPWORDS set from wordcloud
words = [word for word in words if word not in stop_words and word.isalnum()]

# Count word frequencies
word_counts = Counter(words)

# Get the top N most frequent words (adjust N as needed)
top_n = 10
most_common_words = word_counts.most_common(top_n)

# Extract labels and values for the pie chart
labels, values = zip(*most_common_words)

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title(f"Top {top_n} Most Frequent Words")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
#  create a bar graph of the sentiment score

import matplotlib.pyplot as plt

# Sample sentiment scores (replace with your actual sentiment analysis results)
sentiment_scores = {'positive': 0.6, 'negative': 0.2, 'neutral': 0.2}

# Extract labels and values
labels = list(sentiment_scores.keys())
values = list(sentiment_scores.values())

# Create the bar graph
plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.bar(labels, values, color=['green', 'red', 'gray'])  # Customize colors
plt.xlabel('Sentiment')
plt.ylabel('Score')
plt.title('Sentiment Analysis Results')
plt.ylim(0, 1)  # Set y-axis limit for better visualization (0 to 1 for scores)
plt.show()

# %%
#  a bar graph of 100 most used words

# !pip install nltk

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Download the 'averaged_perceptron_tagger_eng' resource
nltk.download('averaged_perceptron_tagger_eng')
import matplotlib.pyplot as plt
from collections import Counter
from google.colab import files
from nltk.corpus import stopwords
nltk.download('stopwords')
# Download the 'punkt_tab' resource for tokenization
nltk.download('punkt_tab') # This line was added to download the missing 'punkt_tab' data


uploaded = files.upload()
filename = list(uploaded.keys())[0]

with open(filename, 'r', encoding='utf-8', errors='ignore') as f:
    text = f.read()

words = nltk.word_tokenize(text.lower())
stop_words = set(stopwords.words('english'))
words = [word for word in words if word not in stop_words and word.isalnum()]


tagged_words = nltk.pos_tag(words)
adjectives_and_nouns = [word for word, tag in tagged_words if tag.startswith('JJ') or tag.startswith('NN')]

word_counts = Counter(adjectives_and_nouns)

most_common_words = word_counts.most_common(100)
labels, values = zip(*most_common_words)

plt.figure(figsize=(20, 8)) # Adjust figure size as needed
plt.bar(labels, values)
plt.xticks(rotation=90)
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("100 Most Frequent Adjectives and Nouns")
plt.show()
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#      <input type="file" id="files-577fe16b-e98e-4083-91c5-94b7e354b869" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-577fe16b-e98e-4083-91c5-94b7e354b869">
#       Upload widget is only available when the cell has been executed in the
# ...
