# %%
from google.colab import files
import os
import shutil

# %% [markdown]
# **Title**: Comparative study between two novels (Anita Desai’s “Fasting & Feasting” and Amitav Ghosh’s “The Calcutta Chromosome ”) using digital tools like - Word Clustering , NER, TopicModeling
#
# **Research Question **
#
# 1."How are gendered experiences and emotional expressions constructed and contrasted in Anita Desai’s Fasting, Feasting and Amitav Ghosh’s The Calcutta Chromosome, and what do these constructions reveal about cultural narratives in Indian English literature?"
#
# 2."In what ways are gendered identities thematically linked to space, emotion, and agency in Fasting, Feasting and The Calcutta Chromosome, and how can digital methods reveal these links?”

# %%
from google.colab import files
import os
import shutil

# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Step 2: Set folder path in Google Drive
folder_path = "/content/drive/My Drive/INDIAN NOVELS"

# Step 3: Upload files from local machine
uploaded = files.upload()  # This will open a file upload dialog

# Step 4: Move uploaded files to the target folder
for filename in uploaded:
    source_path = os.path.join("/content", filename)  # Uploaded files are stored in /content
    destination_path = os.path.join(folder_path, filename)
    shutil.move(source_path, destination_path)

print(f"Files uploaded and moved to: {folder_path}")
# Out:
# Mounted at /content/drive
#      <input type="file" id="files-f7f61cb4-c2ae-4eb1-8d0c-238cd4fa88ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f7f61cb4-c2ae-4eb1-8d0c-238cd4fa88ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !pip install gensim nltk matplotlib scikit-learn seaborn

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Download NLTK stopwords (if not already downloaded)
nltk.download('stopwords')

# Set the folder path in Google Drive
folder_path = "/content/drive/My Drive/INDIAN NOVELS"

# Combine text from all files in the folder
all_text = ""
for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):  # Assuming your documents are text files
        with open(os.path.join(folder_path, filename), "r") as f:
            all_text += f.read()

# Preprocess the text
stop_words = set(stopwords.words('english'))  # Use English stopwords
all_text = all_text.lower()  # Convert to lowercase
words = all_text.split()  # Split into words
filtered_words = [word for word in words if word not in stop_words and word.isalpha()]
processed_text = " ".join(filtered_words)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', stopwords=STOPWORDS).generate(processed_text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-22-0fcc8268c109> in <cell line: 0>()
#      19     if filename.endswith(".txt"):  # Assuming your documents are text files
#      20         with open(os.path.join(folder_path, filename), "r") as f:
# ---> 21             all_text += f.read()
#      22
#      23 # Preprocess the text
#
# /usr/lib/python3.11/codecs.py in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa9 in position 1042: invalid start byte

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Download NLTK stopwords (if not already downloaded)
nltk.download('stopwords')

# Set the folder path in Google Drive
folder_path = "/content/drive/My Drive/INDIAN NOVELS"

# Combine text from all files in the folder
all_text = ""
for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):  # Assuming your documents are text files
        try:
            # Try opening with UTF-8 first
            with open(os.path.join(folder_path, filename), "r", encoding="utf-8") as f:
                all_text += f.read()
        except UnicodeDecodeError:
            # If UTF-8 fails, try 'latin-1' (or 'iso-8859-1')
            with open(os.path.join(folder_path, filename), "r", encoding="latin-1") as f:
                all_text += f.read()

# Preprocess the text
stop_words = set(stopwords.words('english'))  # Use English stopwords
all_text = all_text.lower()  # Convert to lowercase
words = all_text.split()  # Split into words
filtered_words = [word for word in words if word not in stop_words and word.isalpha()]
processed_text = " ".join(filtered_words)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', stopwords=STOPWORDS).generate(processed_text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import nltk
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
import numpy as np # Import numpy for numerical operations

# Download NLTK stopwords (if not already downloaded)
nltk.download('stopwords')

# Set the folder path in Google Drive
folder_path = "/content/drive/My Drive/INDIAN NOVELS"

# Combine text from all files in the folder
all_text = ""
for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):  # Assuming your documents are text files
        try:
            # Try opening with UTF-8 first
            with open(os.path.join(folder_path, filename), "r", encoding="utf-8") as f:
                all_text += f.read()
        except UnicodeDecodeError:
            # If UTF-8 fails, try 'latin-1' (or 'iso-8859-1')
            with open(os.path.join(folder_path, filename), "r", encoding="latin-1") as f:
                all_text += f.read()

# Preprocess the text
stop_words = set(stopwords.words('english'))  # Use English stopwords
all_text = all_text.lower()  # Convert to lowercase
words = all_text.split()  # Split into words
filtered_words = [word for word in words if word not in stop_words and word.isalpha()]

# Specific words to count
target_words = ["mother", "pain", "silence", "eyes", "room", "blood", "fear", "love", "alone", "cry"]

# Count the frequency of target words
word_counts = {word: filtered_words.count(word) for word in target_words}

# Create the bar chart
plt.figure(figsize=(12, 6))
plt.bar(word_counts.keys(), word_counts.values(), color='skyblue')
plt.title('Frequency of Specific Words in Indian Novels')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import nltk
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
import numpy as np

# Download NLTK stopwords (if not already downloaded)
nltk.download('stopwords')

# Set the folder path in Google Drive
folder_path = "/content/drive/My Drive/INDIAN NOVELS"

# Combine text from all files in the folder
all_text = ""
for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):  # Assuming your documents are text files
        try:
            # Try opening with UTF-8 first
            with open(os.path.join(folder_path, filename), "r", encoding="utf-8") as f:
                all_text += f.read()
        except UnicodeDecodeError:
            # If UTF-8 fails, try 'latin-1' (or 'iso-8859-1')
            with open(os.path.join(folder_path, filename), "r", encoding="latin-1") as f:
                all_text += f.read()

# Preprocess the text
stop_words = set(stopwords.words('english'))  # Use English stopwords
all_text = all_text.lower()  # Convert to lowercase
words = all_text.split()  # Split into words
filtered_words = [word for word in words if word not in stop_words and word.isalpha()]

# Specific words to count
target_words = ["man", "power", "war", "control", "money", "fight", "street", "law", "soldier", "fear"]

# Count the frequency of target words
word_counts = {word: filtered_words.count(word) for word in target_words}

# Create the bar chart
plt.figure(figsize=(12, 6))
plt.bar(word_counts.keys(), word_counts.values(), color='skyblue')
plt.title('Frequency of Specific Words in Indian Novels')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !pip install gensim

from google.colab import drive
drive.mount('/content/drive')

import os
import nltk
from nltk.corpus import stopwords


# Download NLTK stopwords (if not already downloaded)
nltk.download('stopwords')
nltk.download('punkt')  # Download punkt for tokenization

# Load pre-trained Word2Vec model


# Set the folder path in Google Drive
folder_path = "/content/drive/My Drive/INDIAN NOVELS"

# Combine text from all files in the folder
all_text = ""
for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):  # Assuming your documents are text files
        try:
            # Try opening with UTF-8 first
            with open(os.path.join(folder_path, filename), "r", encoding="utf-8") as f:
                all_text += f.read()
        except UnicodeDecodeError:
            # If UTF-8 fails, try 'latin-1' (or 'iso-8859-1')
            with open(os.path.join(folder_path, filename), "r", encoding="latin-1") as f:
                all_text += f.read()

# Preprocess the text
stop_words = set(stopwords.words('english'))  # Use English stopwords
all_text = all_text.lower()  # Convert to lowercase

filtered_words = [word for word in words if word not in stop_words and word.isalpha()]


# Target words for semantic analysis
target_words = ["man", "power", "war", "control", "money", "fight", "street", "law", "soldier", "fear",
               "mother", "pain", "silence", "eyes", "room", "blood", "love", "alone", "cry"]

# Find similar words for each target word
for word in target_words:

# !pip install gensim

from google.colab import drive
drive.mount('/content/drive')

import os
import nltk
from nltk.corpus import stopwords


# Download NLTK stopwords (if not already downloaded)
nltk.download('stopwords')
nltk.download('punkt')  # Download punkt for tokenization

# Load pre-trained Word2Vec model


# Set the folder path in Google Drive
folder_path = "/content/drive/My Drive/INDIAN NOVELS"

# Combine text from all files in the folder
all_text = ""
for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):  # Assuming your documents are text files
        try:
            # Try opening with UTF-8 first
            with open(os.path.join(folder_path, filename), "r", encoding="utf-8") as f:
                all_text += f.read()
        except UnicodeDecodeError:
            # If UTF-8 fails, try 'latin-1' (or 'iso-8859-1')
            with open(os.path.join(folder_path, filename), "r", encoding="latin-1") as f:
                all_text += f.read()

# Preprocess the text
stop_words = set(stopwords.words('english'))  # Use English stopwords
all_text = all_text.lower()  # Convert to lowercase

words = nltk.word_tokenize(all_text) # Tokenize the text
filtered_words = [word for word in words if word not in stop_words and word.isalpha()]


# Target words for semantic analysis
target_words = ["man", "power", "war", "control", "money", "fight", "street", "law", "soldier", "fear",
               "mother", "pain", "silence", "eyes", "room", "blood", "love", "alone", "cry"]

# Find similar words for each target word
for word in target_words:
    pass # Add your code here to find similar words
# Out:
#   File "<ipython-input-34-fdb87ce58993>", line 48
#     get_ipython().system('pip install gensim')
#     ^
# IndentationError: expected an indented block after 'for' statement on line 46

# %%
# !pip install gensim

from google.colab import drive
drive.mount('/content/drive')

import os
import nltk
from nltk.corpus import stopwords


# Download NLTK stopwords (if not already downloaded)
nltk.download('stopwords')
nltk.download('punkt')  # Download punkt for tokenization

# Load pre-trained Word2Vec model


# Set the folder path in Google Drive
folder_path = "/content/drive/My Drive/INDIAN NOVELS"

# Combine text from all files in the folder
all_text = ""
for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):  # Assuming your documents are text files
        try:
            # Try opening with UTF-8 first
            with open(os.path.join(folder_path, filename), "r", encoding="utf-8") as f:
                all_text += f.read()
        except UnicodeDecodeError:
            # If UTF-8 fails, try 'latin-1' (or 'iso-8859-1')
            with open(os.path.join(folder_path, filename), "r", encoding="latin-1") as f:
                all_text += f.read()

# Preprocess the text
stop_words = set(stopwords.words('english'))  # Use English stopwords
all_text = all_text.lower()  # Convert to lowercase

words = nltk.word_tokenize(all_text) # Tokenize the text
filtered_words = [word for word in words if word not in stop_words and word.isalpha()]


# Target words for semantic analysis
target_words = ["man", "power", "war", "control", "money", "fight", "street", "law", "soldier", "fear",
               "mother", "pain", "silence", "eyes", "room", "blood", "love", "alone", "cry"]

# Find similar words for each target word
for word in target_words:
    # This is where you would add your code to find and print similar words.
    # For example, using Gensim's Word2Vec:
    # similar_words = model.wv.most_similar(word)
    # print(f"Similar words to '{word}': {similar_words}")
    pass  # Placeholder for your code

# %%
# !pip install gensim

from google.colab import drive
drive.mount('/content/drive')

import os
import nltk
from nltk.corpus import stopwords


# Download NLTK stopwords (if not already downloaded)
nltk.download('stopwords')
nltk.download('punkt')  # Download punkt for tokenization

# Load pre-trained Word2Vec model


# Set the folder path in Google Drive
folder_path = "/content/drive/My Drive/INDIAN NOVELS"

# Combine text from all files in the folder
all_text = ""
for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):  # Assuming your documents are text files
        try:
            # Try opening with UTF-8 first
            with open(os.path.join(folder_path, filename), "r", encoding="utf-8") as f:
                all_text += f.read()
        except UnicodeDecodeError:
            # If UTF-8 fails, try 'latin-1' (or 'iso-8859-1')
            with open(os.path.join(folder_path, filename), "r", encoding="latin-1") as f:
                all_text += f.read()

# Preprocess the text
stop_words = set(stopwords.words('english'))  # Use English stopwords
all_text = all_text.lower()  # Convert to lowercase

words = nltk.word_tokenize(all_text) # Tokenize the text
filtered_words = [word for word in words if word not in stop_words and word.isalpha()]


# Target words for semantic analysis
target_words = ["man", "power", "war", "control", "money", "fight", "street", "law", "soldier", "fear",
               "mother", "pain", "silence", "eyes", "room", "blood", "love", "alone", "cry"]

# Find similar words for each target word
for word in target_words:
    # This is where you would add your code to find and print similar words.
    # For example, using Gensim's Word2Vec:
    # similar_words = model.wv.most_similar(word)
    # print(f"Similar words to '{word}': {similar_words}")
    pass  # Placeholder for your code
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-35-70ec6d3175d8> in <cell line: 0>()
#      36 all_text = all_text.lower()  # Convert to lowercase
#      37
# ---> 38 words = nltk.word_tokenize(all_text) # Tokenize the text
#      39 filtered_words = [word for word in words if word not in stop_words and word.isalpha()]
#      40
#
# /usr/local/lib/python3.11/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     140     :type preserve_line: bool
# ...

# %%
# !pip uninstall numpy scipy gensim -y
# !pip install numpy
# !pip install scipy
# !pip install gensim
# Out:
# Found existing installation: numpy 2.2.4
# Uninstalling numpy-2.2.4:
#   Successfully uninstalled numpy-2.2.4
# Found existing installation: scipy 1.13.1
# Uninstalling scipy-1.13.1:
#   Successfully uninstalled scipy-1.13.1
# Found existing installation: gensim 4.3.2
# Uninstalling gensim-4.3.2:
#   Successfully uninstalled gensim-4.3.2
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 28.4 MB/s eta 0:00:00
# ...
#   Using cached gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# ...
#   Using cached scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# ...
# Using cached gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
# Using cached scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
# ...

# %%
# !pip install gensim

from google.colab import drive
drive.mount('/content/drive')

import os
import nltk
from nltk.corpus import stopwords

# Download NLTK resources
nltk.download('stopwords')
nltk.download('punkt')  # Download punkt for tokenization

# Set the folder path in Google Drive
folder_path = "/content/drive/My Drive/INDIAN NOVELS"

# Combine text from all files in the folder
all_text = ""
for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):  # Assuming your documents are text files
        try:
            # Try opening with UTF-8 first
            with open(os.path.join(folder_path, filename), "r", encoding="utf-8") as f:
                all_text += f.read()
        except UnicodeDecodeError:
            # If UTF-8 fails, try 'latin-1' (or 'iso-8859-1')
            with open(os.path.join(folder_path, filename), "r", encoding="latin-1") as f:
                all_text += f.read()

# Preprocess the text
stop_words = set(stopwords.words('english'))  # Use English stopwords
all_text = all_text.lower()  # Convert to lowercase

# Tokenize the text
words = nltk.word_tokenize(all_text)

# Filter out stop words and non-alphabetic words
filtered_words = [word for word in words if word not in stop_words and word.isalpha()]

# Target words for semantic analysis
target_words = ["man", "power", "war", "control", "money", "fight", "street", "law", "soldier", "fear",
               "mother", "pain", "silence", "eyes", "room", "blood", "love", "alone", "cry"]

# (Rest of your code for semantic analysis would go here)
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-36-545393a182bf> in <cell line: 0>()
#      33
#      34 # Tokenize the text
# ---> 35 words = nltk.word_tokenize(all_text)
#      36
#      37 # Filter out stop words and non-alphabetic words
#
# /usr/local/lib/python3.11/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def clean_text(text):
    text = re.sub(r'\W+', ' ', text.lower())

    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()


texts = [clean_text(doc) for doc in corpus]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# ✅ Install gensim (only once per Colab session)
# !pip install gensim

# ✅ Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# ✅ Import required libraries
import os
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter

# ✅ Download necessary NLTK data
nltk.download('stopwords')
nltk.download('punkt')

# ✅ Set your corpus folder path
folder_path = "/content/drive/My Drive/INDIAN ENGLISH NOVELS"  # update if needed

# ✅ Read and combine text from all files in the folder
all_text = ""
for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):
        file_path = os.path.join(folder_path, filename)
        try:
            with open(file_path, "r", encoding="utf-8") as f:
                all_text += f.read()
        except UnicodeDecodeError:
            with open(file_path, "r", encoding="latin-1") as f:
                all_text += f.read()

# ✅ Preprocess the text
all_text = all_text.lower()
tokens = word_tokenize(all_text)
stop_words = set(stopwords.words("english"))

# ✅ Filter tokens: remove stopwords and non-alphabetic tokens
filtered_words = [word for word in tokens if word.isalpha() and word not in stop_words]

# ✅ Target words for semantic/gender/emotion analysis
target_words = [
    "man", "power", "war", "control", "money", "fight", "street", "law", "soldier", "fear",
    "mother", "pain", "silence", "eyes", "room", "blood", "love", "alone", "cry"
]

# ✅ Count the frequency of target words
word_freq = Counter(filtered_words)
target_freq = {word: word_freq[word] for word in target_words}

# ✅ Display the frequency of target words
import pandas as pd

df = pd.DataFrame(list(target_freq.items()), columns=["Word", "Frequency"])
df = df.sort_values(by="Frequency", ascending=False)
df.reset_index(drop=True, inplace=True)
df
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-58-8fd7056ead81> in <cell line: 0>()
#      22 # ✅ Read and combine text from all files in the folder
#      23 all_text = ""
# ---> 24 for filename in os.listdir(folder_path):
#      25     if filename.endswith(".txt"):
#      26         file_path = os.path.join(folder_path, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/INDIAN ENGLISH NOVELS'

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter

nltk.download("punkt")
nltk.download("stopwords")

# Preprocess
all_text = all_text.lower()
tokens = word_tokenize(all_text)
stop_words = set(stopwords.words("english"))

filtered_words = [word for word in tokens if word.isalpha() and word not in stop_words]

# Target words
target_words = [
    "man", "power", "war", "control", "money", "fight", "street", "law", "soldier", "fear",
    "mother", "pain", "silence", "eyes", "room", "blood", "love", "alone", "cry"
]

# Count frequencies
word_freq = Counter(filtered_words)
target_freq = {word: word_freq[word] for word in target_words}
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-59-105ee7c5afda> in <cell line: 0>()
#       9 # Preprocess
#      10 all_text = all_text.lower()
# ---> 11 tokens = word_tokenize(all_text)
#      12 stop_words = set(stopwords.words("english"))
#      13
#
# /usr/local/lib/python3.11/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
# ...

# %%
# !pip install gensim nltk matplotlib scikit-learn seaborn

import nltk
from nltk.corpus import stopwords
import gensim.downloader as api
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Load pre-trained Word2Vec model (you can choose a different one)
model = api.load('word2vec-google-news-300')

# Target words
target_words = ["man", "power", "war", "control", "money", "fight", "street", "law", "soldier", "fear",
               "mother", "pain", "silence", "eyes", "room", "blood", "love", "alone", "cry"]

# Get word embeddings for target words
word_embeddings = {word: model[word] for word in target_words if word in model}

# Apply t-SNE for dimensionality reduction
tsne = TSNE(n_components=2, random_state=42) # You can adjust random_state
embeddings_2d = tsne.fit_transform(list(word_embeddings.values()))

# Create a DataFrame for plotting
import pandas as pd
df = pd.DataFrame(embeddings_2d, index=word_embeddings.keys(), columns=['x', 'y'])

# Plot the word clusters
plt.figure(figsize=(10, 8))
sns.scatterplot(x='x', y='y', data=df)

# Annotate points with words
for word, pos in df.iterrows():
    plt.annotate(word, pos, fontsize=12, ha='center')

plt.title('Word Clustering using Word2Vec and t-SNE')
plt.show()
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-60-0d077c872ceb> in <cell line: 0>()
#       3 import nltk
#       4 from nltk.corpus import stopwords
# ----> 5 import gensim.downloader as api
#       6 from sklearn.manifold import TSNE
#       7 import matplotlib.pyplot as plt
#
# /usr/local/lib/python3.11/dist-packages/gensim/__init__.py in <module>
#       9 import logging
#      10
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      12
#      13
#
# /usr/local/lib/python3.11/dist-packages/gensim/parsing/__init__.py in <module>
#       2
#       3 from .porter import PorterStemmer  # noqa:F401
# ----> 4 from .preprocessing import (  # noqa:F401
#       5     preprocess_documents,
#       6     preprocess_string,
#
# ...

# %% [markdown]
# # NER

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm

import spacy
nlp = spacy.load("en_core_web_sm")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 56.1 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# **NER EXPLANATION**
#
# As part of the multi-step digital humanities approach, Named Entity Recognition (NER) was conducted to extract and analyze character references and associated entities within the two selected novels. Using the spaCy library and its English language model (en_core_web_sm), the full texts were processed to automatically detect named entities categorized into types such as PERSON, ORG, GPE (geopolitical entities), DATE, and more. This allowed for the identification of key characters, gendered entities, and spatial references embedded in the narrative. The texts were preprocessed by removing extraneous characters and ensuring correct encoding, after which each novel was parsed to extract and store entity-level data. The frequency and distribution of PERSON entities — particularly gender-specific names and pronouns — were analyzed to assess narrative focus and character salience. These entities were saved into CSV files for further filtering and tagging based on gender and thematic roles. Through this NER process, the study revealed how gender visibility functions in the texts: for instance, the frequent recurrence of female entities like “Uma” and “Mama” in Fasting, Feasting reflected the emotional labor and familial expectations placed on women, whereas the dispersed and often implicit presence of characters like “Mangala” in The Calcutta Chromosome pointed to patterns of gendered erasure and historical marginalization. By quantifying and visualizing named entities, the NER method provided a foundational layer for deeper thematic clustering and emotion mapping, allowing the research to connect linguistic structures to cultural patterns of gendered storytelling in Indian English literature.

# %%
import os
import spacy

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# List all .txt files in /content
folder_path = "/content"
txt_files = [f for f in os.listdir(folder_path) if f.endswith(".txt")]

# Run NER on each .txt file
for filename in txt_files:
    file_path = os.path.join(folder_path, filename)

    with open(file_path, "r", encoding="utf-8") as f:
        text = f.read()
        doc = nlp(text)

        print(f"\nNamed Entities in {filename}:\n")
        for ent in doc.ents:
            print(f"{ent.text} ({ent.label_})")
# Out:
# Streaming output truncated to the last 5000 lines.
# three (CARDINAL)
# three (CARDINAL)
# one (CARDINAL)
# three (CARDINAL)
# three (CARDINAL)
# I.
# First Point: (ORG)
# six (CARDINAL)
# late in (TIME)
# Saturday (DATE)
# yesterday (DATE)
# Today (DATE)
# Globe Cinema (ORG)
# Flury’s (ORG)
# Park
# Street (FAC)
# United States (GPE)
# Casio (GPE)
# three (CARDINAL)
# Saturday (DATE)
# half-day (DATE)
# the Wicked Witch (ORG)
# tonight (TIME)
# one (CARDINAL)
# one (CARDINAL)
# five thirty to eight (TIME)
# two (CARDINAL)
# two (CARDINAL)
# five minutes (TIME)
# Sister (PERSON)
# an hour later (TIME)
# one (CARDINAL)
# today (DATE)
# this morning (TIME)
# 12 (CARDINAL)
# Esplanade (LOC)
# Galiff
# Street (ORG)
# two (CARDINAL)
# half an hour (TIME)
# tomorrow (DATE)
# Faraway Tree (ORG)
# evening (TIME)
# night (TIME)
# Bhabani (PERSON)
# veranda (GPE)
# veranda (GPE)
# the night (TIME)
# two (CARDINAL)
# two (CARDINAL)
# Sister (PERSON)
# first (ORDINAL)
# Third (ORDINAL)
# ...

# %%
import os
import spacy
import csv

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# === STEP 1: Set the name of the file you want to process ===
filename = "[Amitav_Ghosh]_The_Calcutta_Chromosome_A_Novel_of(BookFi).txt"  # Change this as needed
file_path = os.path.join("/content", filename)

# === STEP 2: Read the file and run NER ===
with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()
    doc = nlp(text)

    print(f"\nNamed Entities in {filename}:\n")
    for ent in doc.ents:
        print(f"{ent.text} ({ent.label_})")

# === STEP 3: Save the NER results to a CSV ===
output1_csv = f"/content/{filename}_ner_results.csv"  # Output filename includes original filename

with open(output1_csv, "w", newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Entity", "Label"])
    for ent in doc.ents:
        writer.writerow([ent.text, ent.label_])

print(f"\n✅ Results saved to: {output1_csv}")
from google.colab import files
files.download(output1_csv)
# Out:
# Named Entities in [Amitav_Ghosh]_The_Calcutta_Chromosome_A_Novel_of(BookFi).txt:
#
# ALFRED A. KNOPF CANADA (PERSON)
# 1995 (DATE)
# Amitav Ghosh (PERSON)
# International (ORG)
# Pan-American Copyright Conventions (ORG)
# Canada (GPE)
# Alfred A. Knopf Canada (ORG)
# Toronto (GPE)
# Great Britain (GPE)
# Picador (PERSON)
# Macmillan publishers Ltd (ORG)
# London (GPE)
# 1996 (DATE)
# First (ORDINAL)
# 1995 (DATE)
# Ravi Dayal Publisher (ORG)
# New Delhi (GPE)
# Random House of Canada Limited (ORG)
# Toronto (GPE)
# Canadian (NORP)
# Publication Data Ghosh (ORG)
# Amitav (PERSON)
# Calcutta (ORG)
# 1 (CARDINAL)
# 1996 (DATE)
# 823 (CARDINAL)
# C96-930491-9 (PRODUCT)
# Canadian (NORP)
# Cambridge (GPE)
# Chatham (GPE)
# Kent (PERSON)
# Koeli (PERSON)
# This day (DATE)
# Ronald Ross (PERSON)
# (Nobel Prize for Medicine (WORK_OF_ART)
# 1902 (DATE)
# AUGUST (PERSON)
# 20 (CARDINAL)
# MOSQUITO DAY (DATE)
# Chapter 1 (LAW)
# Antar (PRODUCT)
# four-inch (QUANTITY)
# one (CARDINAL)
# ...

# %%
import os
import spacy
import csv

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# === STEP 1: Set the name of the file you want to process ===
filename = "[Anita_Desai]_Fasting,_Feasting(BookFi).txt"  # Change this as needed
file_path = os.path.join("/content", filename)

# === STEP 2: Read the file and run NER ===
with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()
    doc = nlp(text)

    print(f"\nNamed Entities in {filename}:\n")
    for ent in doc.ents:
        print(f"{ent.text} ({ent.label_})")

# === STEP 3: Save the NER results to a CSV ===
output1_csv = f"/content/{filename}_ner_results.csv"  # Output filename includes original filename

with open(output1_csv, "w", newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Entity", "Label"])
    for ent in doc.ents:
        writer.writerow([ent.text, ent.label_])

print(f"\n✅ Results saved to: {output1_csv}")
from google.colab import files
files.download(output1_csv)
# Out:
# Named Entities in [Anita_Desai]_Fasting,_Feasting(BookFi).txt:
#
# Anita Desai
# Fasting (PERSON)
# 1999 (DATE)
# ONE (CARDINAL)
# One (CARDINAL)
# veranda (GPE)
# veranda (GPE)
# Pigeon (PERSON)
# today (DATE)
# Dutt (PERSON)
# Dutt (PERSON)
# Arun (PERSON)
# Shawl- (PERSON)
# 'Shawl? (WORK_OF_ART)
# Kashmir (LOC)
# Brown (PERSON)
# Kashmir Emporium (GPE)
# 'Yes, Papa (WORK_OF_ART)
# Arun (PERSON)
# America (GPE)
# Dutt (PERSON)
# Dutt (PERSON)
# America (GPE)
# Uma (GPE)
# First (ORDINAL)
# Uma (GPE)
# Arun (GPE)
# Dutt (PERSON)
# America (GPE)
# Arun (GPE)
# Dutt (ORG)
# the afternoon (TIME)
# MamaPapa (PRODUCT)
# one (CARDINAL)
# Kanpur (GPE)
# Papa. (ORG)
# Patna (GPE)
# one (CARDINAL)
# my day (DATE)
# Sanskrit (ORG)
# British (NORP)
# Papa (ORG)
# my year studied day (DATE)
# Papa (ORG)
# one (CARDINAL)
# Siamese (NORP)
# veranda (GPE)
# Uma (GPE)
# Papa (ORG)
# morning (TIME)
# Uma (PERSON)
# Aruna (PERSON)
# veranda (GPE)
# Papa (PERSON)
# all morning (TIME)
# Papa (ORG)
# ...

# %%
import os
import spacy
import csv

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# === STEP 1: Set the name of the file you want to process ===
filename = "[Chaudhuri_Amit]_Freedom_Song(BookFi).txt"  # Change this as needed
file_path = os.path.join("/content", filename)

# === STEP 2: Read the file and run NER ===
with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()
    doc = nlp(text)



# === STEP 3: Save the NER results to a CSV ===
output1_csv = f"/content/{filename}_ner_results.csv"  # Output filename includes original filename

with open(output1_csv, "w", newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Entity", "Label"])
    for ent in doc.ents:
        writer.writerow([ent.text, ent.label_])

print(f"\n✅ Results saved to: {output1_csv}")
from google.colab import files
files.download(output1_csv)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-8-7daa69ea1454> in <cell line: 0>()
#      12 # === STEP 2: Read the file and run NER ===
#      13 with open(file_path, "r", encoding="utf-8") as f:
# ---> 14     text = f.read()
#      15     doc = nlp(text)
#      16
#
# /usr/lib/python3.11/codecs.py in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb7 in position 115707: invalid start byte

# %%
import os
import spacy
import csv

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# === STEP 1: Set the name of the file you want to process ===
filename = "[Chaudhuri_Amit]_Freedom_Song(BookFi).txt"  # Change this as needed
file_path = os.path.join("/content", filename)

# === STEP 2: Read the file and run NER ===
# Try opening with 'latin-1' encoding
with open(file_path, "r", encoding="latin-1") as f:  # Changed encoding to 'latin-1'
    text = f.read()
    doc = nlp(text)



# === STEP 3: Save the NER results to a CSV ===
output1_csv = f"/content/{filename}_ner_results.csv"  # Output filename includes original filename

with open(output1_csv, "w", newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Entity", "Label"])
    for ent in doc.ents:
        writer.writerow([ent.text, ent.label_])

print(f"\n✅ Results saved to: {output1_csv}")
from google.colab import files
files.download(output1_csv)
# Out:
# ✅ Results saved to: /content/[Chaudhuri_Amit]_Freedom_Song(BookFi).txt_ner_results.csv

# %%
import os
import spacy
import csv

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# === STEP 1: Set the name of the file you want to process ===
filename = "[R._K._Narayan]_The_Guide(BookFi).txt"  # Change this as needed
file_path = os.path.join("/content", filename)

# === STEP 2: Read the file and run NER ===
# Try opening with 'latin-1' encoding
with open(file_path, "r", encoding="latin-1") as f:  # Changed encoding to 'latin-1'
    text = f.read()
    doc = nlp(text)



# === STEP 3: Save the NER results to a CSV ===
output1_csv = f"/content/{filename}_ner_results.csv"  # Output filename includes original filename

with open(output1_csv, "w", newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Entity", "Label"])
    for ent in doc.ents:
        writer.writerow([ent.text, ent.label_])

print(f"\n✅ Results saved to: {output1_csv}")
from google.colab import files
files.download(output1_csv)
# Out:
# ✅ Results saved to: /content/[R._K._Narayan]_The_Guide(BookFi).txt_ner_results.csv

# %%
import os
import spacy
import csv

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# === STEP 1: Set the name of the file you want to process ===
filename = "[Vikram_Chandra]_Sacred_Games_A_Novel(BookFi) (1).txt"  # Change this as needed
file_path = os.path.join("/content", filename)

# === STEP 2: Read the file and run NER ===
# Try opening with 'latin-1' encoding
with open(file_path, "r", encoding="latin-1") as f:  # Changed encoding to 'latin-1'
    text = f.read()
    doc = nlp(text)



# === STEP 3: Save the NER results to a CSV ===
output1_csv = f"/content/{filename}_ner_results.csv"  # Output filename includes original filename

with open(output1_csv, "w", newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Entity", "Label"])
    for ent in doc.ents:
        writer.writerow([ent.text, ent.label_])

print(f"\n✅ Results saved to: {output1_csv}")
from google.colab import files
files.download(output1_csv)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-b525cb341de9> in <cell line: 0>()
#      14 with open(file_path, "r", encoding="latin-1") as f:  # Changed encoding to 'latin-1'
#      15     text = f.read()
# ---> 16     doc = nlp(text)
#      17
#      18
#
# /usr/local/lib/python3.11/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1038         DOCS: https://spacy.io/api/language#call
#    1039         """
# -> 1040         doc = self._ensure_doc(text)
#    1041         if component_cfg is None:
#    1042             component_cfg = {}
#
# /usr/local/lib/python3.11/dist-packages/spacy/language.py in _ensure_doc(self, doc_like)
#    1129             return doc_like
#    1130         if isinstance(doc_like, str):
# -> 1131             return self.make_doc(doc_like)
#    1132         if isinstance(doc_like, bytes):
# ...

# %%
import os
import spacy
import csv

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# === STEP 1: Set the name of the file you want to process ===
filename = "[Vikram_Chandra]_Sacred_Games_A_Novel(BookFi) (1).txt"  # Change this as needed
file_path = os.path.join("/content", filename)

# === STEP 2: Read the file and run NER ===
# Increase the max_length to handle the large text
nlp.max_length = 3000000  # Adjust this value as needed

# Try opening with 'latin-1' encoding
with open(file_path, "r", encoding="latin-1") as f:  # Changed encoding to 'latin-1'
    text = f.read()
    doc = nlp(text)



# === STEP 3: Save the NER results to a CSV ===
output1_csv = f"/content/{filename}_ner_results.csv"  # Output filename includes original filename

with open(output1_csv, "w", newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Entity", "Label"])
    for ent in doc.ents:
        writer.writerow([ent.text, ent.label_])

print(f"\n✅ Results saved to: {output1_csv}")
from google.colab import files
files.download(output1_csv)
# Out:
# ✅ Results saved to: /content/[Vikram_Chandra]_Sacred_Games_A_Novel(BookFi) (1).txt_ner_results.csv

# %%
# !pip install -q spacy wordcloud matplotlib textblob
# !python -m textblob.download_corpora
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.

# %%
import os
import spacy
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from textblob import TextBlob

# Load spaCy
nlp = spacy.load("en_core_web_sm")

# Specify your filename
filename = "[Amitav_Ghosh]_The_Calcutta_Chromosome_A_Novel_of(BookFi).txt"
file_path = os.path.join("/content", filename)

# Read and process the text
with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()
doc = nlp(text)

# %%
# Count PERSON entities
person_entities = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]
person_freq = Counter(person_entities).most_common(10)

# Bar chart
names, counts = zip(*person_freq)
plt.figure(figsize=(10, 5))
plt.bar(names, counts, color='skyblue')
plt.title("Top 10 Most Mentioned Characters")
plt.xticks(rotation=45)
plt.ylabel("Mentions")
plt.show()

# %%
all_ents = [ent.text for ent in doc.ents]
ent_text = " ".join(all_ents)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(ent_text)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud of All Named Entities")
plt.show()

# %%
from textblob import TextBlob

sentiments = []
for sent in doc.sents:
    blob = TextBlob(sent.text)
    sentiments.append(blob.sentiment.polarity)

# Plot sentiment histogram
plt.figure(figsize=(10, 5))
plt.hist(sentiments, bins=20, color='lightcoral', edgecolor='black')
plt.title("Sentiment Distribution Across Sentences")
plt.xlabel("Polarity (Negative to Positive)")
plt.ylabel("Number of Sentences")
plt.grid(True)
plt.show()

# %%
import os
import spacy
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from textblob import TextBlob

# Load spaCy
nlp = spacy.load("en_core_web_sm")

# Specify your filename
filename = "[Anita_Desai]_Fasting,_Feasting(BookFi).txt"
file_path = os.path.join("/content", filename)

# Read and process the text
with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()
doc = nlp(text)

# %%
# Count PERSON entities
person_entities = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]
person_freq = Counter(person_entities).most_common(10)

# Bar chart
names, counts = zip(*person_freq)
plt.figure(figsize=(10, 5))
plt.bar(names, counts, color='skyblue')
plt.title("Top 10 Most Mentioned Characters")
plt.xticks(rotation=45)
plt.ylabel("Mentions")
plt.show()

# %%
all_ents = [ent.text for ent in doc.ents]
ent_text = " ".join(all_ents)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(ent_text)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud of All Named Entities")
plt.show()

# %%
from textblob import TextBlob

sentiments = []
for sent in doc.sents:
    blob = TextBlob(sent.text)
    sentiments.append(blob.sentiment.polarity)

# Plot sentiment histogram
plt.figure(figsize=(10, 5))
plt.hist(sentiments, bins=20, color='lightcoral', edgecolor='black')
plt.title("Sentiment Distribution Across Sentences")
plt.xlabel("Polarity (Negative to Positive)")
plt.ylabel("Number of Sentences")
plt.grid(True)
plt.show()

# %%
import spacy
from collections import Counter
import string
import matplotlib.pyplot as plt

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Read and process the file
filename = "[Amitav_Ghosh]_The_Calcutta_Chromosome_A_Novel_of(BookFi).txt"
file_path = f"/content/{filename}"

with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()
doc = nlp(text)

# Get named entities so we can exclude them from word frequency
named_entities = {ent.text for ent in doc.ents}

# Filter tokens: remove stopwords, punctuation, spaces, named entities, digits
words = [
    token.text.lower()
    for token in doc
    if token.is_alpha                         # only words, no punctuation
    and not token.is_stop                     # remove stopwords like "the", "and"
    and token.text not in named_entities      # remove named entities
]

# Count most frequent words
word_freq = Counter(words).most_common(20)

# Display as a bar chart
words, counts = zip(*word_freq)
plt.figure(figsize=(12, 6))
plt.bar(words, counts, color='slateblue')
plt.xticks(rotation=45)
plt.title("Top 20 Most Frequent Words (excluding stopwords & named entities)")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
import spacy
from collections import Counter
import string
import matplotlib.pyplot as plt

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Read and process the file
filename = "[Anita_Desai]_Fasting,_Feasting(BookFi).txt"
file_path = f"/content/{filename}"

with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()
doc = nlp(text)

# Get named entities so we can exclude them from word frequency
named_entities = {ent.text for ent in doc.ents}

# Filter tokens: remove stopwords, punctuation, spaces, named entities, digits
words = [
    token.text.lower()
    for token in doc
    if token.is_alpha                         # only words, no punctuation
    and not token.is_stop                     # remove stopwords like "the", "and"
    and token.text not in named_entities      # remove named entities
]

# Count most frequent words
word_freq = Counter(words).most_common(20)

# Display as a bar chart
words, counts = zip(*word_freq)
plt.figure(figsize=(12, 6))
plt.bar(words, counts, color='slateblue')
plt.xticks(rotation=45)
plt.title("Top 20 Most Frequent Words (excluding stopwords & named entities)")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
import os
import spacy
import csv

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# === STEP 1: Set the name of the file you want to process ===
filename = "Red Earth and Pouring Rain_ A N - Vikram Chandra.txt"  # Change this as needed
file_path = os.path.join("/content", filename)

# === STEP 2: Read the file and run NER ===
# Try opening with 'latin-1' encoding
with open(file_path, "r", encoding="latin-1") as f:  # Changed encoding to 'latin-1'
    text = f.read()
    doc = nlp(text)



# === STEP 3: Save the NER results to a CSV ===
output1_csv = f"/content/{filename}_ner_results.csv"  # Output filename includes original filename

with open(output1_csv, "w", newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Entity", "Label"])
    for ent in doc.ents:
        writer.writerow([ent.text, ent.label_])

print(f"\n✅ Results saved to: {output1_csv}")
from google.colab import files
files.download(output1_csv)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-2387d44fbf6a> in <cell line: 0>()
#      14 with open(file_path, "r", encoding="latin-1") as f:  # Changed encoding to 'latin-1'
#      15     text = f.read()
# ---> 16     doc = nlp(text)
#      17
#      18
#
# /usr/local/lib/python3.11/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1038         DOCS: https://spacy.io/api/language#call
#    1039         """
# -> 1040         doc = self._ensure_doc(text)
#    1041         if component_cfg is None:
#    1042             component_cfg = {}
#
# /usr/local/lib/python3.11/dist-packages/spacy/language.py in _ensure_doc(self, doc_like)
#    1129             return doc_like
#    1130         if isinstance(doc_like, str):
# -> 1131             return self.make_doc(doc_like)
#    1132         if isinstance(doc_like, bytes):
# ...

# %%
import os
import spacy
import csv

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# === STEP 1: Set the name of the file you want to process ===
filename = "Red Earth and Pouring Rain_ A N - Vikram Chandra.txt"  # Change this as needed
file_path = os.path.join("/content", filename)

# === STEP 2: Read the file and run NER ===
# Increase the max_length to handle the large text
nlp.max_length = 3000000  # Adjust this value as needed

# Try opening with 'latin-1' encoding
with open(file_path, "r", encoding="latin-1") as f:  # Changed encoding to 'latin-1'
    text = f.read()
    doc = nlp(text)



# === STEP 3: Save the NER results to a CSV ===
output1_csv = f"/content/{filename}_ner_results.csv"  # Output filename includes original filename

with open(output1_csv, "w", newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Entity", "Label"])
    for ent in doc.ents:
        writer.writerow([ent.text, ent.label_])

print(f"\n✅ Results saved to: {output1_csv}")
from google.colab import files
files.download(output1_csv)
# Out:
# ✅ Results saved to: /content/Red Earth and Pouring Rain_ A N - Vikram Chandra.txt_ner_results.csv

# %%
import os
import spacy
import csv

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# === STEP 1: Set the name of the file you want to process ===
filename = ""  # Change this as needed
file_path = os.path.join("/content", filename)

# === STEP 2: Read the file and run NER ===
# Increase the max_length to handle the large text
nlp.max_length = 3000000  # Adjust this value as needed

# Try opening with 'latin-1' encoding
with open(file_path, "r", encoding="latin-1") as f:  # Changed encoding to 'latin-1'
    text = f.read()
    doc = nlp(text)



# === STEP 3: Save the NER results to a CSV ===
output1_csv = f"/content/{filename}_ner_results.csv"  # Output filename includes original filename

with open(output1_csv, "w", newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Entity", "Label"])
    for ent in doc.ents:
        writer.writerow([ent.text, ent.label_])

print(f"\n✅ Results saved to: {output1_csv}")
from google.colab import files
files.download(output1_csv)

# %%
import spacy
from collections import Counter
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# Load spaCy model with word vectors
nlp = spacy.load("en_core_web_md")

# Read the text
filename = "[Amitav_Ghosh]_The_Calcutta_Chromosome_A_Novel_of(BookFi).txt"
file_path = f"/content/{filename}"

with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()
doc = nlp(text)

# Filter tokens: real words, not stopwords/punct/digits/named entities
named_entities = {ent.text for ent in doc.ents}

words = [
    token.text.lower()
    for token in doc
    if token.is_alpha
    and not token.is_stop
    and token.text not in named_entities
]

# Get top 100 frequent words
top_words = [word for word, _ in Counter(words).most_common(100)]

# Get word vectors
word_vecs = np.array([nlp(word).vector for word in top_words if nlp(word).has_vector])
filtered_words = [word for word in top_words if nlp(word).has_vector]

# Clustering with KMeans
num_clusters = 5  # You can adjust this
kmeans = KMeans(n_clusters=num_clusters, random_state=0, n_init='auto')
labels = kmeans.fit_predict(word_vecs)

# Reduce dimensions for plotting
pca = PCA(n_components=2)
reduced = pca.fit_transform(word_vecs)

# Plot
plt.figure(figsize=(12, 8))
colors = ['red', 'blue', 'green', 'purple', 'orange']
for i in range(num_clusters):
    xs = reduced[labels == i, 0]
    ys = reduced[labels == i, 1]
    plt.scatter(xs, ys, color=colors[i], label=f'Cluster {i+1}', alpha=0.6)

# Add word labels
for i, word in enumerate(filtered_words):
    plt.text(reduced[i, 0]+0.1, reduced[i, 1]+0.1, word, fontsize=9)

plt.title("Word Clusters from Text (PCA + KMeans)")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.legend()
plt.grid(True)
plt.show()

# %%
# !python -m spacy download en_core_web_md
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 30.0 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
from collections import Counter
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# Load spaCy model with word vectors
nlp = spacy.load("en_core_web_md")

# Read the text
filename = "[Anita_Desai]_Fasting,_Feasting(BookFi).txt"
file_path = f"/content/{filename}"

with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()
doc = nlp(text)

# Filter tokens: real words, not stopwords/punct/digits/named entities
named_entities = {ent.text for ent in doc.ents}

words = [
    token.text.lower()
    for token in doc
    if token.is_alpha
    and not token.is_stop
    and token.text not in named_entities
]

# Get top 100 frequent words
top_words = [word for word, _ in Counter(words).most_common(100)]

# Get word vectors
word_vecs = np.array([nlp(word).vector for word in top_words if nlp(word).has_vector])
filtered_words = [word for word in top_words if nlp(word).has_vector]

# Clustering with KMeans
num_clusters = 5  # You can adjust this
kmeans = KMeans(n_clusters=num_clusters, random_state=0, n_init='auto')
labels = kmeans.fit_predict(word_vecs)

# Reduce dimensions for plotting
pca = PCA(n_components=2)
reduced = pca.fit_transform(word_vecs)

# Plot
plt.figure(figsize=(12, 8))
colors = ['red', 'blue', 'green', 'purple', 'orange']
for i in range(num_clusters):
    xs = reduced[labels == i, 0]
    ys = reduced[labels == i, 1]
    plt.scatter(xs, ys, color=colors[i], label=f'Cluster {i+1}', alpha=0.6)

# Add word labels
for i, word in enumerate(filtered_words):
    plt.text(reduced[i, 0]+0.1, reduced[i, 1]+0.1, word, fontsize=9)

plt.title("Word Clusters from Text (PCA + KMeans)")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.legend()
plt.grid(True)
plt.show()

# %%
import os
import spacy
import csv

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# === STEP 1: Set the name of the file you want to process ===
filename = "The Blue Bedspread - Raj Kamal Jha.txt"  # Change this as needed
file_path = os.path.join("/content", filename)

# === STEP 2: Read the file and run NER ===
# Increase the max_length to handle the large text
nlp.max_length = 3000000  # Adjust this value as needed

# Try opening with 'latin-1' encoding
with open(file_path, "r", encoding="latin-1") as f:  # Changed encoding to 'latin-1'
    text = f.read()
    doc = nlp(text)



# === STEP 3: Save the NER results to a CSV ===
output1_csv = f"/content/{filename}_ner_results.csv"  # Output filename includes original filename

with open(output1_csv, "w", newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Entity", "Label"])
    for ent in doc.ents:
        writer.writerow([ent.text, ent.label_])

print(f"\n✅ Results saved to: {output1_csv}")
from google.colab import files
files.download(output1_csv)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-5b579b9e5db6> in <cell line: 0>()
#      15
#      16 # Try opening with 'latin-1' encoding
# ---> 17 with open(file_path, "r", encoding="latin-1") as f:  # Changed encoding to 'latin-1'
#      18     text = f.read()
#      19     doc = nlp(text)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/The Blue Bedspread - Raj Kamal Jha.txt'

# %%
import os
import spacy
import csv

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# === STEP 1: Set the name of the file you want to process ===
filename = "The Blue Bedspread - Raj Kamal Jha.txt"  # Change this as needed

# Make sure the file is uploaded or available in the correct location
# For example, if using Google Colab:
from google.colab import files
uploaded = files.upload()  # This will prompt you to upload the file

# OR, if the file is already in your Google Drive:
# from google.colab import drive
# drive.mount('/content/drive')
# file_path = "/content/drive/My Drive/path/to/your/file.txt" # Update with the actual path

file_path = os.path.join("/content", filename)  # Assuming you uploaded the file

# === STEP 2: Read the file and run NER ===
# Increase the max_length to handle the large text
nlp.max_length = 3000000  # Adjust this value as needed

# Try opening with 'latin-1' encoding
with open(file_path, "r", encoding="latin-1") as f:  # Changed encoding to 'latin-1'
    text = f.read()
    doc = nlp(text)



# === STEP 3: Save the NER results to a CSV ===
output1_csv = f"/content/{filename}_ner_results.csv"  # Output filename includes original filename

with open(output1_csv, "w", newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Entity", "Label"])
    for ent in doc.ents:
        writer.writerow([ent.text, ent.label_])

print(f"\n✅ Results saved to: {output1_csv}")
from google.colab import files
files.download(output1_csv)
# Out:
#      <input type="file" id="files-19cb426c-44c9-4359-848d-50d3d33a6de2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-19cb426c-44c9-4359-848d-50d3d33a6de2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from gensim import corpora, models

# Create dictionary and corpus
dictionary = corpora.Dictionary([filtered_tokens])
doc_term_matrix = [dictionary.doc2bow(filtered_tokens)]

# LDA Model
LDA = models.LdaModel
lda_model = LDA(corpus=doc_term_matrix, id2word=dictionary, num_topics=5, passes=10)

for idx, topic in lda_model.print_topics(-1):
    print(f"Topic {idx}: {topic}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-8767632a5ff0> in <cell line: 0>()
# ----> 1 from gensim import corpora, models
#       2
#       3 # Create dictionary and corpus
#       4 dictionary = corpora.Dictionary([filtered_tokens])
#       5 doc_term_matrix = [dictionary.doc2bow(filtered_tokens)]
#
# ModuleNotFoundError: No module named 'gensim'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
